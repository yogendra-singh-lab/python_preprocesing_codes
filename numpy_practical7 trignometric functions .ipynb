# %% [markdown]
# # numpy trignometric functions sin(

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(180)
# Out:
# -0.8011526357338304

# %%
np.cos(0)
# Out:
# 1.0

# %%
np.tan(45)
# Out:
# 1.6197751905438615

# %%
x_sin = np.arange(0,360,15)
print(x_sin)
# Out:
# [  0  15  30  45  60  75  90 105 120 135 150 165 180 195 210 225 240 255
#  270 285 300 315 330 345]

# %%
np.pi
# Out:
# 3.141592653589793

# %%
y_sin = np.sin(x_sin)
print(y_sin)
# Out:
# [ 0.          0.65028784 -0.98803162  0.85090352 -0.30481062 -0.38778164
#   0.89399666 -0.97053528  0.58061118  0.08836869 -0.71487643  0.99779728
#  -0.80115264  0.21945467  0.46771852 -0.93009488  0.94544515 -0.50639163
#  -0.17604595  0.77387159 -0.99975584  0.74513326 -0.13238163 -0.54399582]

# %%
plt.plot(x_sin,y_sin)
plt.show()# plotting the trignometric function graph

# %%
y_cos = np.cos(x_sin)
plt.plot(x_sin,y_cos)
plt.show()

# %%
y_tan = np.tan(x_sin)
plt.plot(x_sin,y_tan)
plt.show()
