# %% [markdown]
# # data cleaning for cat variables

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\machine learning data sets\\train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2 = df.select_dtypes(include = ['object'])
df2
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
cat1 = df2.isnull().sum()/df.shape[0]*100
cat1
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
df.shape[0]
# Out:
# 1460

# %%
drop_col =  cat1[cat1>20].keys()
drop_col
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df3 = df2.drop(columns = ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'])
df3
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
sns.heatmap(df3.isnull())
# Out:
# <AxesSubplot:>

# %%
cat2 = df3.isnull().sum()/df3.shape[0]*100
df4 = cat2[cat2>0].keys()
df4
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
# to impute value on nan categorical values we use mode to fill thge nan valuesdf4
df3['MasVnrType'].fillna('missing')
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
#          ...
# 1455       None
# 1456      Stone
# 1457       None
# 1458       None
# 1459       None
# Name: MasVnrType, Length: 1460, dtype: object

# %%
df3['MasVnrType'].mode()
# Out:
# 0    None
# dtype: object

# %%
df3['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %% [markdown]
# df3['MasVnrType'].fillna(df3['MasVnrType'].mode())

# %%
df3['MasVnrType'].fillna(df3['MasVnrType'].mode()[0])
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
#          ...
# 1455       None
# 1456      Stone
# 1457       None
# 1458       None
# 1459       None
# Name: MasVnrType, Length: 1460, dtype: object

# %%
for var in df4:
    df3[var].fillna(df3[var].mode()[0],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5f2f2b75e8c> in <module>
# ----> 1 for var in df4:
#       2     df3[var].fillna(df3[var].mode()[0],inplace = True)
#
# NameError: name 'df4' is not defined

# %%
df3.isnull().sum().sum()
# Out:
# 0
